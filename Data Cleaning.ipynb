# %%
import pandas as pd
import datetime
import json

# %%
# US data into dataframe
df = pd.read_csv('./output/20.10.02_US_videos.csv') 
df.head()
# Out:
#       video_id                                              title  \
# 0  87zXvSCmSYk   Joaquin Phoenix Accepts the Oscar for Lead Actor
# 1  J8AGD_p8F6I  The Oscars 2020 | Legendary comeback from Emin...
# 2  M3Y_B7fNmjA                      The Most Underrated Game Ever
# 3  XGtMMYWhdUU                        Papa John - H3 Podcast #174
# 4  SczPkU9_aHs  Official Call of Duty®: Modern Warfare® – Seas...
#
#                 publishedAt                 channelId       channelTitle  \
# 0  2020-02-10T04:24:30.000Z  UC_IpSl6O_-IRAA6fiNs05Gg                ABC
# 1  2020-02-10T17:05:08.000Z  UCokpOoe2OrddBfl6I_oY5vQ      FOX Nederland
# 2  2020-02-09T19:03:24.000Z  UCGwu0nbY2wSkW8N-cghnLpA  Jaiden Animations
# 3  2020-02-10T22:16:40.000Z  UCLtREJY21xRfCuEKvdki1Kw         H3 Podcast
# 4  2020-02-10T18:00:49.000Z  UC9YydG57epLqxA9cTzZXSeQ       Call of Duty
#
#    categoryId trending_date  \
# 0          24      20.10.02
# 1          24      20.10.02
# 2           1      20.10.02
# 3          24      20.10.02
# 4          20      20.10.02
#
#                                                 tags  view_count   likes  \
# 0  oscars|academy|awards|statue|ceremony|red|carp...     2194152   84843
# 1  the oscars|92nd academy awards|the academy awa...     2723978  185470
# 2  jaiden|animations|jaidenanimation|jaidenanimat...     2800708  237998
# 3  h3 podcast|h3h3 podcast|the h3 podcast|the h3h...      243383   34371
# 4  call of duty|cod|activision|mw|modern|warfare|...      223399   18253
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      4961          14947  https://i.ytimg.com/vi/87zXvSCmSYk/default.jpg
# 1      2775          14030  https://i.ytimg.com/vi/J8AGD_p8F6I/default.jpg
# 2      3176          34357  https://i.ytimg.com/vi/M3Y_B7fNmjA/default.jpg
# 3       427           7435  https://i.ytimg.com/vi/XGtMMYWhdUU/default.jpg
# 4       966           2021  https://i.ytimg.com/vi/SczPkU9_aHs/default.jpg
#
#    comments_disabled  ratings_disabled  \
# 0              False             False
# 1              False             False
# 2              False             False
# 3              False             False
# 4              False             False
#
#                                          description
# 0  Watch Joaquin Phoenix's Oscar 2020 acceptance ...
# 1  Eminem verraste de gehele zaal, en vervolgens ...
# 2  dino time gets weirdChuggaconroy: https://www....
# 3  A huge thanks to Papa John for coming on!TEDDY...
# 4  The War Rages On.✅ More Weapons✅ More Maps✅ Mo...

# %%
# Remove unecessary columns
df = df.drop(['channelId', 'thumbnail_link', 'comments_disabled', 'ratings_disabled'], axis=1)
df.head()
# Out:
#       video_id                                              title  \
# 0  87zXvSCmSYk   Joaquin Phoenix Accepts the Oscar for Lead Actor
# 1  J8AGD_p8F6I  The Oscars 2020 | Legendary comeback from Emin...
# 2  M3Y_B7fNmjA                      The Most Underrated Game Ever
# 3  XGtMMYWhdUU                        Papa John - H3 Podcast #174
# 4  SczPkU9_aHs  Official Call of Duty®: Modern Warfare® – Seas...
#
#                 publishedAt       channelTitle  categoryId trending_date  \
# 0  2020-02-10T04:24:30.000Z                ABC          24      20.10.02
# 1  2020-02-10T17:05:08.000Z      FOX Nederland          24      20.10.02
# 2  2020-02-09T19:03:24.000Z  Jaiden Animations           1      20.10.02
# 3  2020-02-10T22:16:40.000Z         H3 Podcast          24      20.10.02
# 4  2020-02-10T18:00:49.000Z       Call of Duty          20      20.10.02
#
#                                                 tags  view_count   likes  \
# 0  oscars|academy|awards|statue|ceremony|red|carp...     2194152   84843
# 1  the oscars|92nd academy awards|the academy awa...     2723978  185470
# 2  jaiden|animations|jaidenanimation|jaidenanimat...     2800708  237998
# 3  h3 podcast|h3h3 podcast|the h3 podcast|the h3h...      243383   34371
# 4  call of duty|cod|activision|mw|modern|warfare|...      223399   18253
#
#    dislikes  comment_count                                        description
# 0      4961          14947  Watch Joaquin Phoenix's Oscar 2020 acceptance ...
# 1      2775          14030  Eminem verraste de gehele zaal, en vervolgens ...
# 2      3176          34357  dino time gets weirdChuggaconroy: https://www....
# 3       427           7435  A huge thanks to Papa John for coming on!TEDDY...
# 4       966           2021  The War Rages On.✅ More Weapons✅ More Maps✅ Mo...

# %%
# Reformate published date
df['publishedAt'] = df['publishedAt'].apply(lambda x: x[2:10])
df['publishedAt'] = df['publishedAt'].apply(lambda x: str(x).replace('-', '.'))
df.head()
# Out:
#       video_id                                              title publishedAt  \
# 0  87zXvSCmSYk   Joaquin Phoenix Accepts the Oscar for Lead Actor    20.02.10
# 1  J8AGD_p8F6I  The Oscars 2020 | Legendary comeback from Emin...    20.02.10
# 2  M3Y_B7fNmjA                      The Most Underrated Game Ever    20.02.09
# 3  XGtMMYWhdUU                        Papa John - H3 Podcast #174    20.02.10
# 4  SczPkU9_aHs  Official Call of Duty®: Modern Warfare® – Seas...    20.02.10
#
#         channelTitle  categoryId trending_date  \
# 0                ABC          24      20.10.02
# 1      FOX Nederland          24      20.10.02
# 2  Jaiden Animations           1      20.10.02
# 3         H3 Podcast          24      20.10.02
# 4       Call of Duty          20      20.10.02
#
#                                                 tags  view_count   likes  \
# 0  oscars|academy|awards|statue|ceremony|red|carp...     2194152   84843
# 1  the oscars|92nd academy awards|the academy awa...     2723978  185470
# 2  jaiden|animations|jaidenanimation|jaidenanimat...     2800708  237998
# 3  h3 podcast|h3h3 podcast|the h3 podcast|the h3h...      243383   34371
# 4  call of duty|cod|activision|mw|modern|warfare|...      223399   18253
#
#    dislikes  comment_count                                        description
# 0      4961          14947  Watch Joaquin Phoenix's Oscar 2020 acceptance ...
# 1      2775          14030  Eminem verraste de gehele zaal, en vervolgens ...
# 2      3176          34357  dino time gets weirdChuggaconroy: https://www....
# 3       427           7435  A huge thanks to Papa John for coming on!TEDDY...
# 4       966           2021  The War Rages On.✅ More Weapons✅ More Maps✅ Mo...

# %%
# Reformat trending date
df['trending_date'] = df['trending_date'].apply(lambda x: datetime.datetime.strptime(str(x), '%y.%d.%m').strftime('%y.%m.%d'))
df['trending_date']
# Out:
# 0      20.02.10
# 1      20.02.10
# 2      20.02.10
# 3      20.02.10
# 4      20.02.10
#          ...
# 195    20.02.10
# 196    20.02.10
# 197    20.02.10
# 198    20.02.10
# 199    20.02.10
# Name: trending_date, Length: 200, dtype: object

# %%
# Split tags
df['tags'] = df['tags'].apply(lambda x: str(x).split('|'))
df
# Out:
#         video_id                                              title  \
# 0    87zXvSCmSYk   Joaquin Phoenix Accepts the Oscar for Lead Actor
# 1    J8AGD_p8F6I  The Oscars 2020 | Legendary comeback from Emin...
# 2    M3Y_B7fNmjA                      The Most Underrated Game Ever
# 3    XGtMMYWhdUU                        Papa John - H3 Podcast #174
# 4    SczPkU9_aHs  Official Call of Duty®: Modern Warfare® – Seas...
# ..           ...                                                ...
# 195  62EB4JniuTc         “Big Game” Spot | Marvel Studios | Disney+
# 196  iaqcwyZPuKg  Patriot Act Bonus: Hasan Sits Down With Bernie...
# 197  gwAOxH0EEJI       The Bella Twins’ PREGNANCY DETAILS revealed!
# 198  62v-g_2Xaf0  Building Ikea's most difficult furniture: THE ...
# 199  sE1ESYmanro       I Have A Secret Admirer At School! *SO CUTE*
#
#     publishedAt          channelTitle  categoryId trending_date  \
# 0      20.02.10                   ABC          24      20.02.10
# 1      20.02.10         FOX Nederland          24      20.02.10
# 2      20.02.09     Jaiden Animations           1      20.02.10
# 3      20.02.10            H3 Podcast          24      20.02.10
# 4      20.02.10          Call of Duty          20      20.02.10
# ..          ...                   ...         ...           ...
# 195    20.02.03  Marvel Entertainment          24      20.02.10
# 196    20.02.03           Patriot Act          22      20.02.10
# 197    20.02.03       The Bella Twins          22      20.02.10
# 198    20.02.03            The Grumps          23      20.02.10
# 199    20.02.02          Dan and Riya          23      20.02.10
#
#                                                   tags  view_count   likes  \
# 0    [oscars, academy, awards, statue, ceremony, re...     2194152   84843
# 1    [the oscars, 92nd academy awards, the academy ...     2723978  185470
# 2    [jaiden, animations, jaidenanimation, jaidenan...     2800708  237998
# 3    [h3 podcast, h3h3 podcast, the h3 podcast, the...      243383   34371
# 4    [call of duty, cod, activision, mw, modern, wa...      223399   18253
# ..                                                 ...         ...     ...
# 195  [marvel, comics, wandavision, falcon and the w...     5784350  217284
# 196  [Netflix, Patriot Act with Hasan Minhaj, Patri...     1076606   46942
# 197  [the bella twin, bellas, brie bella, nikki bel...     1497590   62278
# 198  [egoraptor, danny, game grumps, gamegrumps, fu...      550390   31157
# 199  [danandriya, dan and riya, riya and dan, dan r...     2082949   39675
#
#      dislikes  comment_count  \
# 0        4961          14947
# 1        2775          14030
# 2        3176          34357
# 3         427           7435
# 4         966           2021
# ..        ...            ...
# 195      3312           9519
# 196      1351           6280
# 197      1111           5055
# 198       464           2671
# 199      2022           7275
#
#                                            description
# 0    Watch Joaquin Phoenix's Oscar 2020 acceptance ...
# 1    Eminem verraste de gehele zaal, en vervolgens ...
# 2    dino time gets weirdChuggaconroy: https://www....
# 3    A huge thanks to Papa John for coming on!TEDDY...
# 4    The War Rages On.✅ More Weapons✅ More Maps✅ Mo...
# ..                                                 ...
# 195  The Universe is expanding. Marvel Studios’ The...
# 196  Hasan recently interviewed 2020 presidential c...
# 197  Nikki & Brie, THE BELLA MOMS, dish on details ...
# 198  You've seen Arin and Dan play the newlywed gam...
# 199  It’s Valentine's day and everyone at my high s...
#
# [200 rows x 12 columns]

# %%
# Get category by number
cat_dict = {}

with open('./output/US_category_id.json') as f:
    data = json.loads(f.read())
    for i in range(0, 32):
        cat_dict[data['items'][i]['id']] = data['items'][i]['snippet']['title']
    
    
 
# for i in range(0, 32):
cat_dict
# Out:
# {'1': 'Film & Animation',
#  '2': 'Autos & Vehicles',
#  '10': 'Music',
#  '15': 'Pets & Animals',
#  '17': 'Sports',
#  '18': 'Short Movies',
#  '19': 'Travel & Events',
#  '20': 'Gaming',
#  '21': 'Videoblogging',
#  '22': 'People & Blogs',
#  '23': 'Comedy',
#  '24': 'Entertainment',
#  '25': 'News & Politics',
#  '26': 'Howto & Style',
#  '27': 'Education',
#  '28': 'Science & Technology',
#  '29': 'Nonprofits & Activism',
#  '30': 'Movies',
#  '31': 'Anime/Animation',
#  '32': 'Action/Adventure',
#  '33': 'Classics',
#  '34': 'Comedy',
#  '35': 'Documentary',
#  '36': 'Drama',
#  '37': 'Family',
#  '38': 'Foreign',
#  '39': 'Horror',
#  '40': 'Sci-Fi/Fantasy',
#  '41': 'Thriller',
#  '42': 'Shorts',
#  '43': 'Shows',
#  '44': 'Trailers'}

# %%
# Convert category number to category name
df['categoryId'] = df['categoryId'].apply(lambda x: cat_dict[str(x)])
df
# Out:
#         video_id                                              title  \
# 0    87zXvSCmSYk   Joaquin Phoenix Accepts the Oscar for Lead Actor
# 1    J8AGD_p8F6I  The Oscars 2020 | Legendary comeback from Emin...
# 2    M3Y_B7fNmjA                      The Most Underrated Game Ever
# 3    XGtMMYWhdUU                        Papa John - H3 Podcast #174
# 4    SczPkU9_aHs  Official Call of Duty®: Modern Warfare® – Seas...
# ..           ...                                                ...
# 195  62EB4JniuTc         “Big Game” Spot | Marvel Studios | Disney+
# 196  iaqcwyZPuKg  Patriot Act Bonus: Hasan Sits Down With Bernie...
# 197  gwAOxH0EEJI       The Bella Twins’ PREGNANCY DETAILS revealed!
# 198  62v-g_2Xaf0  Building Ikea's most difficult furniture: THE ...
# 199  sE1ESYmanro       I Have A Secret Admirer At School! *SO CUTE*
#
#     publishedAt          channelTitle        categoryId trending_date  \
# 0      20.02.10                   ABC     Entertainment      20.02.10
# 1      20.02.10         FOX Nederland     Entertainment      20.02.10
# 2      20.02.09     Jaiden Animations  Film & Animation      20.02.10
# 3      20.02.10            H3 Podcast     Entertainment      20.02.10
# 4      20.02.10          Call of Duty            Gaming      20.02.10
# ..          ...                   ...               ...           ...
# 195    20.02.03  Marvel Entertainment     Entertainment      20.02.10
# 196    20.02.03           Patriot Act    People & Blogs      20.02.10
# 197    20.02.03       The Bella Twins    People & Blogs      20.02.10
# 198    20.02.03            The Grumps            Comedy      20.02.10
# 199    20.02.02          Dan and Riya            Comedy      20.02.10
#
#                                                   tags  view_count   likes  \
# 0    [oscars, academy, awards, statue, ceremony, re...     2194152   84843
# 1    [the oscars, 92nd academy awards, the academy ...     2723978  185470
# 2    [jaiden, animations, jaidenanimation, jaidenan...     2800708  237998
# 3    [h3 podcast, h3h3 podcast, the h3 podcast, the...      243383   34371
# 4    [call of duty, cod, activision, mw, modern, wa...      223399   18253
# ..                                                 ...         ...     ...
# 195  [marvel, comics, wandavision, falcon and the w...     5784350  217284
# 196  [Netflix, Patriot Act with Hasan Minhaj, Patri...     1076606   46942
# 197  [the bella twin, bellas, brie bella, nikki bel...     1497590   62278
# 198  [egoraptor, danny, game grumps, gamegrumps, fu...      550390   31157
# 199  [danandriya, dan and riya, riya and dan, dan r...     2082949   39675
#
#      dislikes  comment_count  \
# 0        4961          14947
# 1        2775          14030
# 2        3176          34357
# 3         427           7435
# 4         966           2021
# ..        ...            ...
# 195      3312           9519
# 196      1351           6280
# 197      1111           5055
# 198       464           2671
# 199      2022           7275
#
#                                            description
# 0    Watch Joaquin Phoenix's Oscar 2020 acceptance ...
# 1    Eminem verraste de gehele zaal, en vervolgens ...
# 2    dino time gets weirdChuggaconroy: https://www....
# 3    A huge thanks to Papa John for coming on!TEDDY...
# 4    The War Rages On.✅ More Weapons✅ More Maps✅ Mo...
# ..                                                 ...
# 195  The Universe is expanding. Marvel Studios’ The...
# 196  Hasan recently interviewed 2020 presidential c...
# 197  Nikki & Brie, THE BELLA MOMS, dish on details ...
# 198  You've seen Arin and Dan play the newlywed gam...
# 199  It’s Valentine's day and everyone at my high s...
#
# [200 rows x 12 columns]

# %%
# convert back to csv
df.to_csv('./output/US_cleaned_data_2018')
